# %% [markdown]
# <a href="https://colab.research.google.com/github/santfan/module_11/blob/main/module_11_2_google.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Импортируем нужные библиотеки
import inspect
from pprint import pprint

# %%
# Объявим функцию
def introspection_info(obj):
  # Создадим пустой словарь значений
  info_dic = {}
  # Отловим ошибки ввода
  try:
    print(f'Исследуем объект {obj}')
  except AttributeError as ex:
    print(f'Ошибка {ex} значение {ex.args}')
  # К какому модулю принадлежит объект
  print('Модуль, к которому объект принадлежит:', inspect.getmodule(obj), sep='\n\t')
  info_dic['Модуль'] = inspect.getmodule(obj)
  # Тип объекта
  print('Тип объекта: ', type(obj), sep='\n\t')
  info_dic['Тип'] = type(obj)
  # Атрибуты объекта
  print('Атрибуты объекта: ', dir(obj), sep='\n\t')
  info_dic['Атрибуты'] = dir(obj)
  # Создадим пустой список методов
  metod_lst = []
  # Пробежим по методам
  for atr_name in dir(obj):
    atr = getattr(obj, atr_name)
    # Если к методу можно обратиться то добавим в лист
    if callable(atr):
      metod_lst.append(atr)
    print(f'Метод - Имя: {atr_name} Тип: {str(type(atr))} Исполняемый: {callable(atr)}')
    info_dic['Методы'] = metod_lst
  # Для функций
  if inspect.isfunction(obj):
    sig_vol = inspect.signature(obj)
    print('Передаваемый в функцию параметры:', sig_vol.parameters, sep='\n\t')
    param_list = []
    # пробежим по параметрам
    for p_name, param in sig_vol.parameters.items():
      # Имя и значение по умолчанию (если есть)
      param_list.append([param.name, param.default])
      info_dic['Параметры'] = param_list
  # Вернем итоговый словарь
  return info_dic

# %%
# Исследуем простое число
info = introspection_info(42)
pprint(info)
# Out:
# Исследуем объект 42
# Модуль, к которому объект принадлежит:
# 	None
# Тип объекта:
# 	<class 'int'>
# Атрибуты объекта:
# 	['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']
# Метод - Имя: __abs__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __add__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __and__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __bool__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __ceil__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __class__ Тип: <class 'type'> Исполняемый: True
# Метод - Имя: __delattr__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __dir__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __divmod__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __doc__ Тип: <class 'str'> Исполняемый: False
# Метод - Имя: __eq__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __float__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __floor__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __floordiv__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __format__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __ge__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __getattribute__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __getnewargs__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __gt__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __hash__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __index__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __init__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __init_subclass__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __int__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __invert__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __le__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __lshift__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __lt__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __mod__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __mul__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __ne__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __neg__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __new__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __or__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __pos__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __pow__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __radd__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rand__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rdivmod__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __reduce__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __reduce_ex__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __repr__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rfloordiv__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rlshift__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rmod__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rmul__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __ror__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __round__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __rpow__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rrshift__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rshift__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rsub__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rtruediv__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __rxor__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __setattr__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __sizeof__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __str__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __sub__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __subclasshook__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __truediv__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __trunc__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __xor__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: as_integer_ratio Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: bit_count Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: bit_length Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: conjugate Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: denominator Тип: <class 'int'> Исполняемый: False
# Метод - Имя: from_bytes Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: imag Тип: <class 'int'> Исполняемый: False
# Метод - Имя: numerator Тип: <class 'int'> Исполняемый: False
# Метод - Имя: real Тип: <class 'int'> Исполняемый: False
# Метод - Имя: to_bytes Тип: <class 'builtin_function_or_method'> Исполняемый: True
# {'Атрибуты': ['__abs__',
#               '__add__',
#               '__and__',
#               '__bool__',
#               '__ceil__',
#               '__class__',
#               '__delattr__',
#               '__dir__',
#               '__divmod__',
#               '__doc__',
#               '__eq__',
#               '__float__',
#               '__floor__',
#               '__floordiv__',
#               '__format__',
#               '__ge__',
#               '__getattribute__',
#               '__getnewargs__',
#               '__gt__',
#               '__hash__',
#               '__index__',
#               '__init__',
#               '__init_subclass__',
#               '__int__',
#               '__invert__',
#               '__le__',
#               '__lshift__',
#               '__lt__',
#               '__mod__',
#               '__mul__',
#               '__ne__',
#               '__neg__',
#               '__new__',
#               '__or__',
#               '__pos__',
#               '__pow__',
#               '__radd__',
#               '__rand__',
#               '__rdivmod__',
#               '__reduce__',
#               '__reduce_ex__',
#               '__repr__',
#               '__rfloordiv__',
#               '__rlshift__',
#               '__rmod__',
#               '__rmul__',
#               '__ror__',
#               '__round__',
#               '__rpow__',
#               '__rrshift__',
#               '__rshift__',
#               '__rsub__',
#               '__rtruediv__',
#               '__rxor__',
#               '__setattr__',
#               '__sizeof__',
#               '__str__',
#               '__sub__',
#               '__subclasshook__',
#               '__truediv__',
#               '__trunc__',
#               '__xor__',
#               'as_integer_ratio',
#               'bit_count',
#               'bit_length',
#               'conjugate',
#               'denominator',
#               'from_bytes',
#               'imag',
#               'numerator',
#               'real',
#               'to_bytes'],
#  'Методы': [<method-wrapper '__abs__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__add__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__and__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__bool__' of int object at 0x7fcf57698610>,
#             <built-in method __ceil__ of int object at 0x7fcf57698610>,
#             <class 'int'>,
#             <method-wrapper '__delattr__' of int object at 0x7fcf57698610>,
#             <built-in method __dir__ of int object at 0x7fcf57698610>,
#             <method-wrapper '__divmod__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__eq__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__float__' of int object at 0x7fcf57698610>,
#             <built-in method __floor__ of int object at 0x7fcf57698610>,
#             <method-wrapper '__floordiv__' of int object at 0x7fcf57698610>,
#             <built-in method __format__ of int object at 0x7fcf57698610>,
#             <method-wrapper '__ge__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__getattribute__' of int object at 0x7fcf57698610>,
#             <built-in method __getnewargs__ of int object at 0x7fcf57698610>,
#             <method-wrapper '__gt__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__hash__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__index__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__init__' of int object at 0x7fcf57698610>,
#             <built-in method __init_subclass__ of type object at 0x56cb75f81320>,
#             <method-wrapper '__int__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__invert__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__le__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__lshift__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__lt__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__mod__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__mul__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__ne__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__neg__' of int object at 0x7fcf57698610>,
#             <built-in method __new__ of type object at 0x56cb75f81320>,
#             <method-wrapper '__or__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__pos__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__pow__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__radd__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rand__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rdivmod__' of int object at 0x7fcf57698610>,
#             <built-in method __reduce__ of int object at 0x7fcf57698610>,
#             <built-in method __reduce_ex__ of int object at 0x7fcf57698610>,
#             <method-wrapper '__repr__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rfloordiv__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rlshift__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rmod__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rmul__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__ror__' of int object at 0x7fcf57698610>,
#             <built-in method __round__ of int object at 0x7fcf57698610>,
#             <method-wrapper '__rpow__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rrshift__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rshift__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rsub__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rtruediv__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__rxor__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__setattr__' of int object at 0x7fcf57698610>,
#             <built-in method __sizeof__ of int object at 0x7fcf57698610>,
#             <method-wrapper '__str__' of int object at 0x7fcf57698610>,
#             <method-wrapper '__sub__' of int object at 0x7fcf57698610>,
#             <built-in method __subclasshook__ of type object at 0x56cb75f81320>,
#             <method-wrapper '__truediv__' of int object at 0x7fcf57698610>,
#             <built-in method __trunc__ of int object at 0x7fcf57698610>,
#             <method-wrapper '__xor__' of int object at 0x7fcf57698610>,
#             <built-in method as_integer_ratio of int object at 0x7fcf57698610>,
#             <built-in method bit_count of int object at 0x7fcf57698610>,
#             <built-in method bit_length of int object at 0x7fcf57698610>,
#             <built-in method conjugate of int object at 0x7fcf57698610>,
#             <built-in method from_bytes of type object at 0x56cb75f81320>,
#             <built-in method to_bytes of int object at 0x7fcf57698610>],
#  'Модуль': None,
#  'Тип': <class 'int'>}

# %%
# Исследуем встроенную функцию print()
info = introspection_info(print)
pprint(info)
# Out:
# Исследуем объект <built-in function print>
# Модуль, к которому объект принадлежит:
# 	<module 'builtins' (built-in)>
# Тип объекта:
# 	<class 'builtin_function_or_method'>
# Атрибуты объекта:
# 	['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__text_signature__']
# Метод - Имя: __call__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __class__ Тип: <class 'type'> Исполняемый: True
# Метод - Имя: __delattr__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __dir__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __doc__ Тип: <class 'str'> Исполняемый: False
# Метод - Имя: __eq__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __format__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __ge__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __getattribute__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __gt__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __hash__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __init__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __init_subclass__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __le__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __lt__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __module__ Тип: <class 'str'> Исполняемый: False
# Метод - Имя: __name__ Тип: <class 'str'> Исполняемый: False
# Метод - Имя: __ne__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __new__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __qualname__ Тип: <class 'str'> Исполняемый: False
# Метод - Имя: __reduce__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __reduce_ex__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __repr__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __self__ Тип: <class 'module'> Исполняемый: False
# Метод - Имя: __setattr__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __sizeof__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __str__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __subclasshook__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __text_signature__ Тип: <class 'NoneType'> Исполняемый: False
# {'Атрибуты': ['__call__',
#               '__class__',
#               '__delattr__',
#               '__dir__',
#               '__doc__',
#               '__eq__',
#               '__format__',
#               '__ge__',
#               '__getattribute__',
#               '__gt__',
#               '__hash__',
#               '__init__',
#               '__init_subclass__',
#               '__le__',
#               '__lt__',
#               '__module__',
#               '__name__',
#               '__ne__',
#               '__new__',
#               '__qualname__',
#               '__reduce__',
#               '__reduce_ex__',
#               '__repr__',
#               '__self__',
#               '__setattr__',
#               '__sizeof__',
#               '__str__',
#               '__subclasshook__',
#               '__text_signature__'],
#  'Методы': [<method-wrapper '__call__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <class 'builtin_function_or_method'>,
#             <method-wrapper '__delattr__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <built-in method __dir__ of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__eq__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <built-in method __format__ of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__ge__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__getattribute__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__gt__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__hash__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__init__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <built-in method __init_subclass__ of type object at 0x56cb75f788a0>,
#             <method-wrapper '__le__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__lt__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__ne__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <built-in method __new__ of type object at 0x56cb75f81800>,
#             <built-in method __reduce__ of builtin_function_or_method object at 0x7fcf5772d530>,
#             <built-in method __reduce_ex__ of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__repr__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__setattr__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <built-in method __sizeof__ of builtin_function_or_method object at 0x7fcf5772d530>,
#             <method-wrapper '__str__' of builtin_function_or_method object at 0x7fcf5772d530>,
#             <built-in method __subclasshook__ of type object at 0x56cb75f788a0>],
#  'Модуль': <module 'builtins' (built-in)>,
#  'Тип': <class 'builtin_function_or_method'>}

# %%
# Для теста объявим класс
class TestClass():
  # Класс в данном случае ничего не делает
  pass

# %%
# Создадим экземпляр класса
clas_1 = TestClass()

# %%
# Проведем инспекцию
info = introspection_info(clas_1)
pprint(info)
# Out:
# Исследуем объект <__main__.TestClass object at 0x7fcf086a2680>
# Модуль, к которому объект принадлежит:
# 	<module '__main__'>
# Тип объекта:
# 	<class '__main__.TestClass'>
# Атрибуты объекта:
# 	['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__']
# Метод - Имя: __class__ Тип: <class 'type'> Исполняемый: True
# Метод - Имя: __delattr__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __dict__ Тип: <class 'dict'> Исполняемый: False
# Метод - Имя: __dir__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __doc__ Тип: <class 'NoneType'> Исполняемый: False
# Метод - Имя: __eq__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __format__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __ge__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __getattribute__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __gt__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __hash__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __init__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __init_subclass__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __le__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __lt__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __module__ Тип: <class 'str'> Исполняемый: False
# Метод - Имя: __ne__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __new__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __reduce__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __reduce_ex__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __repr__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __setattr__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __sizeof__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __str__ Тип: <class 'method-wrapper'> Исполняемый: True
# Метод - Имя: __subclasshook__ Тип: <class 'builtin_function_or_method'> Исполняемый: True
# Метод - Имя: __weakref__ Тип: <class 'NoneType'> Исполняемый: False
# {'Атрибуты': ['__class__',
#               '__delattr__',
#               '__dict__',
#               '__dir__',
#               '__doc__',
#               '__eq__',
#               '__format__',
#               '__ge__',
#               '__getattribute__',
#               '__gt__',
#               '__hash__',
#               '__init__',
#               '__init_subclass__',
#               '__le__',
#               '__lt__',
#               '__module__',
#               '__ne__',
#               '__new__',
#               '__reduce__',
#               '__reduce_ex__',
#               '__repr__',
#               '__setattr__',
#               '__sizeof__',
#               '__str__',
#               '__subclasshook__',
#               '__weakref__'],
#  'Методы': [<class '__main__.TestClass'>,
#             <method-wrapper '__delattr__' of TestClass object at 0x7fcf086a2680>,
#             <built-in method __dir__ of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__eq__' of TestClass object at 0x7fcf086a2680>,
#             <built-in method __format__ of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__ge__' of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__getattribute__' of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__gt__' of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__hash__' of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__init__' of TestClass object at 0x7fcf086a2680>,
#             <built-in method __init_subclass__ of type object at 0x56cb7a4c05a0>,
#             <method-wrapper '__le__' of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__lt__' of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__ne__' of TestClass object at 0x7fcf086a2680>,
#             <built-in method __new__ of type object at 0x56cb75f81800>,
#             <built-in method __reduce__ of TestClass object at 0x7fcf086a2680>,
#             <built-in method __reduce_ex__ of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__repr__' of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__setattr__' of TestClass object at 0x7fcf086a2680>,
#             <built-in method __sizeof__ of TestClass object at 0x7fcf086a2680>,
#             <method-wrapper '__str__' of TestClass object at 0x7fcf086a2680>,
#             <built-in method __subclasshook__ of type object at 0x56cb7a4c05a0>],
#  'Модуль': <module '__main__'>,
#  'Тип': <class '__main__.TestClass'>}
